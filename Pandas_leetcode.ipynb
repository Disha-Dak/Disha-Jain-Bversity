# %% [markdown]
# Write a solution to create a DataFrame from a 2D list called student_data. This 2D list contains the IDs and ages of some students.
#
# The DataFrame should have two columns, student_id and age, and be in the same order as the original 2D list.
#
# The result format is in the following example.
#
#
#
# Example 1:
#
# Input:
# student_data:
# [
#   [1, 15],
#   [2, 11],
#   [3, 11],
#   [4, 20]
# ]

# %%
import pandas as pd
student_data = [ [1, 15], [2, 11], [3, 11], [4, 20] ]

# %%
student_data
# Out:
# [[1, 15], [2, 11], [3, 11], [4, 20]]

# %%
import pandas as pd

# Create DataFrame with correct column names
df = pd.DataFrame(student_data, columns=['student_id', 'age'])

# Display the DataFrame
print(df)
# Out:
#    student_id  age
# 0           1   15
# 1           2   11
# 2           3   11
# 3           4   20

# %%
import pandas as pd


student_data = [
    [101, 20],
    [102, 21],
    [103, 19],
    [104, 22]
]

# Function to create a DataFrame from a 2D list
def createDataframe(student_data):
    # Create DataFrame with appropriate column names
    return pd.DataFrame(student_data, columns=["student_id", "age"])
print(student_data)
# Out:
# [[101, 20], [102, 21], [103, 19], [104, 22]]

# %%
df_1 = pd.DataFrame(student_data, columns=["student_id", "age"])
print(student_data)
# Out:
# [[101, 20], [102, 21], [103, 19], [104, 22]]

# %% [markdown]
# DataFrame players:
# +-------------+--------+
# | Column Name | Type   |
# +-------------+--------+
# | player_id   | int    |
# | name        | object |
# | age         | int    |
# | position    | object |
# | ...         | ...    |
# +-------------+--------+
# Write a solution to calculate and display the number of rows and columns of players.
#
# Return the result as an array:
#
# [number of rows, number of columns]
#
# The result format is in the following example.

# %%
import pandas as pd

def get_shape(players):
    # Calculate the number of rows and columns using the shape attribute
    rows, columns = players.shape
    # Return the result as an array
    return [rows, columns]

# Example input DataFrame
data = {
    'player_id': [1, 2, 3],
    'name': ['Alice', 'Bob', 'Charlie'],
    'age': [25, 30, 22],
    'position': ['Forward', 'Midfielder', 'Defender']
}

players = pd.DataFrame(data)

# Call the function and print the result
result = get_shape(players)
print(result)
# Out:
# [3, 4]

# %%
print(len(df['age']))  # Number of rows in the "age" column
# Out:
# 4

# %%
import pandas as pd
data = pd.read_csv("Pandas.csv")   #Reading a file

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Inspecting the data
print("/n first  5 rows")
print(df.head())
print("/n last  5 rows")
print(df.tail())
print("/n random 5 rows")
print(df.sample())
print("/n Summary of the data set")
print(df.info())
print("/n Statistic of the data set")
print(df.describe())
# Out:
# /n first  5 rows
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0
# /n last  5 rows
#     Duration          Date  Pulse  Maxpulse  Calories
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132       NaN
# 29        60  '2020/12/29'    100       132     280.0
# 30        60  '2020/12/30'    102       129     380.3
# 31        60  '2020/12/31'     92       115     243.0
# /n random 5 rows
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# /n Summary of the data set
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
# ...

# %%
df.columns
# Out:
# Index(['Duration', 'Date', 'Pulse', 'Maxpulse', 'Calories'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=32, step=1)

# %%
#Selection and indexing of the data 
df['Date']
# Out:
# 0     '2020/12/01'
# 1     '2020/12/02'
# 2     '2020/12/03'
# 3     '2020/12/04'
# 4     '2020/12/05'
# 5     '2020/12/06'
# 6     '2020/12/07'
# 7     '2020/12/08'
# 8     '2020/12/09'
# 9     '2020/12/10'
# 10    '2020/12/11'
# 11    '2020/12/12'
# 12    '2020/12/12'
# 13    '2020/12/13'
# 14    '2020/12/14'
# 15    '2020/12/15'
# 16    '2020/12/16'
# 17    '2020/12/17'
# 18    '2020/12/18'
# 19    '2020/12/19'
# 20    '2020/12/20'
# 21    '2020/12/21'
# 22             NaN
# 23    '2020/12/23'
# 24    '2020/12/24'
# 25    '2020/12/25'
# 26        20201226
# 27    '2020/12/27'
# 28    '2020/12/28'
# 29    '2020/12/29'
# 30    '2020/12/30'
# 31    '2020/12/31'
# Name: Date, dtype: object

# %%
df[['Pulse','Duration']]   #Selecting two columns use two brackets
# Out:
#     Pulse  Duration
# 0     110        60
# 1     117        60
# 2     103        60
# 3     109        45
# 4     117        45
# 5     102        60
# 6     110        60
# 7     104       450
# 8     109        30
# 9      98        60
# 10    103        60
# 11    100        60
# 12    100        60
# 13    106        60
# 14    104        60
# 15     98        60
# 16     98        60
# 17    100        60
# 18     90        45
# 19    103        60
# 20     97        45
# 21    108        60
# 22    100        45
# 23    130        60
# 24    105        45
# 25    102        60
# 26    100        60
# 27     92        60
# 28    103        60
# 29    100        60
# 30    102        60
# 31     92        60

# %%
df.iloc[0]   #first complete row by position
# Out:
# Duration              60
# Date        '2020/12/01'
# Pulse                110
# Maxpulse             130
# Calories           409.1
# Name: 0, dtype: object

# %%
df.loc[0]  #first complete row by index label
# Out:
# Duration              60
# Date        '2020/12/01'
# Pulse                110
# Maxpulse             130
# Calories           409.1
# Name: 0, dtype: object

# %%
df.iloc[0,1]   #select element by position  #column wise
# Out:
# "'2020/12/01'"

# %%
df.iloc[0,4]     #select element by position  #column wise #[start , end]
# Out:
# np.float64(409.1)

# %%
df.iloc[0,5]   #there is nothing at the fifth position and hence the key error
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.iloc[0,5]
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:4211, in DataFrame._get_value(self, index, col, takeable)
#    4192 """
#    4193 Quickly retrieve single value at passed column and index.
#    4194
#    (...)
#    4208 `self.columns._index_as_unique`; Caller is responsible for checking.
#    4209 """
#    4210 if takeable:
# ...

# %%
df.loc[2,'Date'] #Select a specific element by label.
# Out:
# "'2020/12/03'"

# %%
df.loc[3,'Duration']
# Out:
# np.int64(45)

# %%
#Index
df.set_index('Date')
# Out:
#               Duration  Pulse  Maxpulse  Calories
# Date
# '2020/12/01'        60    110       130     409.1
# '2020/12/02'        60    117       145     479.0
# '2020/12/03'        60    103       135     340.0
# '2020/12/04'        45    109       175     282.4
# '2020/12/05'        45    117       148     406.0
# '2020/12/06'        60    102       127     300.0
# '2020/12/07'        60    110       136     374.0
# '2020/12/08'       450    104       134     253.3
# '2020/12/09'        30    109       133     195.1
# '2020/12/10'        60     98       124     269.0
# '2020/12/11'        60    103       147     329.3
# '2020/12/12'        60    100       120     250.7
# '2020/12/12'        60    100       120     250.7
# '2020/12/13'        60    106       128     345.3
# '2020/12/14'        60    104       132     379.3
# '2020/12/15'        60     98       123     275.0
# '2020/12/16'        60     98       120     215.2
# '2020/12/17'        60    100       120     300.0
# ...

# %%
#Cleaning the data 
print("/n The missing the value")
print(df.isnull().sum())
# Out:
# /n The missing the value
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df.notnull()
# Out:
#     Duration   Date  Pulse  Maxpulse  Calories
# 0       True   True   True      True      True
# 1       True   True   True      True      True
# 2       True   True   True      True      True
# 3       True   True   True      True      True
# 4       True   True   True      True      True
# 5       True   True   True      True      True
# 6       True   True   True      True      True
# 7       True   True   True      True      True
# 8       True   True   True      True      True
# 9       True   True   True      True      True
# 10      True   True   True      True      True
# 11      True   True   True      True      True
# 12      True   True   True      True      True
# 13      True   True   True      True      True
# 14      True   True   True      True      True
# 15      True   True   True      True      True
# 16      True   True   True      True      True
# 17      True   True   True      True      True
# 18      True   True   True      True     False
# ...

# %%
df.dropna()   #dropped the missing value
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#feeling the missing value
df = df.fillna(df.mode().iloc[0])
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.drop_duplicates()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# 16        60  '2020/12/16'     98       120     215.2
# ...

# %%
#Sorting the data 
df.sort_values('Duration')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 8         30  '2020/12/09'    109       133     195.1
# 20        45  '2020/12/20'     97       125     243.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 22        45  '2020/12/12'    100       119     282.0
# 18        45  '2020/12/18'     90       112     300.0
# 24        45  '2020/12/24'    105       132     246.0
# 19        60  '2020/12/19'    103       123     323.0
# 21        60  '2020/12/21'    108       131     364.2
# 23        60  '2020/12/23'    130       101     300.0
# 0         60  '2020/12/01'    110       130     409.1
# 26        60      20201226    100       120     250.0
# 27        60  '2020/12/27'     92       118     241.0
# 28        60  '2020/12/28'    103       132     300.0
# 29        60  '2020/12/29'    100       132     280.0
# 25        60  '2020/12/25'    102       126     334.5
# ...

# %%
#Sorting the data 
df.sort_values('Duration', ascending = False)
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 7        450  '2020/12/08'    104       134     253.3
# 0         60  '2020/12/01'    110       130     409.1
# 15        60  '2020/12/15'     98       123     275.0
# 30        60  '2020/12/30'    102       129     380.3
# 29        60  '2020/12/29'    100       132     280.0
# 28        60  '2020/12/28'    103       132     300.0
# 27        60  '2020/12/27'     92       118     241.0
# 26        60      20201226    100       120     250.0
# 25        60  '2020/12/25'    102       126     334.5
# 23        60  '2020/12/23'    130       101     300.0
# 21        60  '2020/12/21'    108       131     364.2
# 19        60  '2020/12/19'    103       123     323.0
# 17        60  '2020/12/17'    100       120     300.0
# 1         60  '2020/12/02'    117       145     479.0
# 16        60  '2020/12/16'     98       120     215.2
# 14        60  '2020/12/14'    104       132     379.3
# ...

# %%
df.sort_values(['Duration' , 'Maxpulse'], ascending = [True, False])
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 8         30  '2020/12/09'    109       133     195.1
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 24        45  '2020/12/24'    105       132     246.0
# 20        45  '2020/12/20'     97       125     243.0
# 22        45  '2020/12/12'    100       119     282.0
# 18        45  '2020/12/18'     90       112     300.0
# 10        60  '2020/12/11'    103       147     329.3
# 1         60  '2020/12/02'    117       145     479.0
# 6         60  '2020/12/07'    110       136     374.0
# 2         60  '2020/12/03'    103       135     340.0
# 14        60  '2020/12/14'    104       132     379.3
# 28        60  '2020/12/28'    103       132     300.0
# 29        60  '2020/12/29'    100       132     280.0
# 21        60  '2020/12/21'    108       131     364.2
# 0         60  '2020/12/01'    110       130     409.1
# ...

# %%
#filter based on condition
df[df['Pulse'] > 100]
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 10        60  '2020/12/11'    103       147     329.3
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 19        60  '2020/12/19'    103       123     323.0
# 21        60  '2020/12/21'    108       131     364.2
# 23        60  '2020/12/23'    130       101     300.0
# 24        45  '2020/12/24'    105       132     246.0
# ...

# %%
df.nlargest(3,'Pulse')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 23        60  '2020/12/23'    130       101     300.0
# 1         60  '2020/12/02'    117       145     479.0
# 4         45  '2020/12/05'    117       148     406.0

# %%
df.nlargest(5,'Pulse')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 23        60  '2020/12/23'    130       101     300.0
# 1         60  '2020/12/02'    117       145     479.0
# 4         45  '2020/12/05'    117       148     406.0
# 0         60  '2020/12/01'    110       130     409.1
# 6         60  '2020/12/07'    110       136     374.0

# %%
df.nsmallest(5,'Pulse')
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 18        45  '2020/12/18'     90       112     300.0
# 27        60  '2020/12/27'     92       118     241.0
# 31        60  '2020/12/31'     92       115     243.0
# 20        45  '2020/12/20'     97       125     243.0
# 9         60  '2020/12/10'     98       124     269.0

# %%
#Aggregation of the data 
grouped = df.groupby('Duration')
grouped

# %%
aggregations = {
    'Duration': ['mean', 'sum', 'max', 'min', 'count'],
    'Pulse': ['mean', 'std', 'max', 'min'],
    'Maxpulse': ['mean', 'max', 'min'],
    'Calories': ['mean', 'sum', 'max', 'min']
}

# Apply the aggregation
agg_results = df.agg(aggregations)

print(agg_results)
# Out:
#         Duration       Pulse  Maxpulse   Calories
# mean     68.4375  103.500000     128.5   304.3875
# sum    2190.0000         NaN       NaN  9740.4000
# max     450.0000  130.000000     175.0   479.0000
# min      30.0000   90.000000     101.0   195.1000
# count    32.0000         NaN       NaN        NaN
# std          NaN    7.832933       NaN        NaN

# %%
pulse_counts = (df['Pulse'].value_counts())
pulse_countsdf
# Out:
# Pulse
# 100    6
# 103    4
# 102    3
# 98     3
# 110    2
# 117    2
# 109    2
# 104    2
# 92     2
# 106    1
# 90     1
# 97     1
# 108    1
# 130    1
# 105    1
# Name: count, dtype: int64

# %%
agg1=df.agg({'Pulse' :'sum' , 'Maxpulse' :'mean'})
agg1
# Out:
# Pulse       3312.0
# Maxpulse     128.5
# dtype: float64

# %%
df.T
# Out:
#                     0             1             2             3   \
# Duration            60            60            60            45
# Date      '2020/12/01'  '2020/12/02'  '2020/12/03'  '2020/12/04'
# Pulse              110           117           103           109
# Maxpulse           130           145           135           175
# Calories         409.1         479.0         340.0         282.4
#
#                     4             5             6             7   \
# Duration            45            60            60           450
# Date      '2020/12/05'  '2020/12/06'  '2020/12/07'  '2020/12/08'
# Pulse              117           102           110           104
# Maxpulse           148           127           136           134
# Calories         406.0         300.0         374.0         253.3
#
#                     8             9   ...            22            23  \
# Duration            30            60  ...            45            60
# ...

# %%
#pivot table
df.pivot_table(values = 'Pulse' , index = 'Duration' , aggfunc = 'sum')
# Out:
#           Pulse
# Duration
# 30          109
# 45          618
# 60         2481
# 450         104

# %%
#merging and joining data
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
#Merging the data

# %% [markdown]
# 1.pd.concat([df1, df2]): Concatenate
# DataFrames vertically.
# 2.pd.concat([df1, df2], axis=1):
# Concatenate DataFrames
# horizontally.
# 3.df1.merge(df2, on='key'): Merge two
# DataFrames on a key.
# df1.join(df2): SQL-style

# %%
#Statistical analysis
print(df['Pulse'].mean())
print(df['Pulse'].median())
# Out:
# 103.5
# 102.5

# %%
df['Pulse'].corr(df['Maxpulse'])
# Out:
# np.float64(0.2765834823573775)

# %%
df['Pulse'].plot(kind='line')
# Out:
# <Axes: >

# %%
df['Pulse'].plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Pulse'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Pulse'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Age'] = [0] * len(df)  # This will assign 0 to all rows in the 'Age' column
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories  Age
# 0         60  '2020/12/01'    110       130     409.1    0
# 1         60  '2020/12/02'    117       145     479.0    0
# 2         60  '2020/12/03'    103       135     340.0    0
# 3         45  '2020/12/04'    109       175     282.4    0
# 4         45  '2020/12/05'    117       148     406.0    0
# 5         60  '2020/12/06'    102       127     300.0    0
# 6         60  '2020/12/07'    110       136     374.0    0
# 7        450  '2020/12/08'    104       134     253.3    0
# 8         30  '2020/12/09'    109       133     195.1    0
# 9         60  '2020/12/10'     98       124     269.0    0
# 10        60  '2020/12/11'    103       147     329.3    0
# 11        60  '2020/12/12'    100       120     250.7    0
# 12        60  '2020/12/12'    100       120     250.7    0
# 13        60  '2020/12/13'    106       128     345.3    0
# 14        60  '2020/12/14'    104       132     379.3    0
# ...

# %%
df['Age'] = None  # This will assign 0 to all rows in the 'Age' column
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories   Age
# 0         60  '2020/12/01'    110       130     409.1  None
# 1         60  '2020/12/02'    117       145     479.0  None
# 2         60  '2020/12/03'    103       135     340.0  None
# 3         45  '2020/12/04'    109       175     282.4  None
# 4         45  '2020/12/05'    117       148     406.0  None
# 5         60  '2020/12/06'    102       127     300.0  None
# 6         60  '2020/12/07'    110       136     374.0  None
# 7        450  '2020/12/08'    104       134     253.3  None
# 8         30  '2020/12/09'    109       133     195.1  None
# 9         60  '2020/12/10'     98       124     269.0  None
# 10        60  '2020/12/11'    103       147     329.3  None
# 11        60  '2020/12/12'    100       120     250.7  None
# 12        60  '2020/12/12'    100       120     250.7  None
# 13        60  '2020/12/13'    106       128     345.3  None
# 14        60  '2020/12/14'    104       132     379.3  None
# ...

# %%
df.rename(columns={'Age': 'Years'}, inplace=True)
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories Years
# 0         60  '2020/12/01'    110       130     409.1  None
# 1         60  '2020/12/02'    117       145     479.0  None
# 2         60  '2020/12/03'    103       135     340.0  None
# 3         45  '2020/12/04'    109       175     282.4  None
# 4         45  '2020/12/05'    117       148     406.0  None
# 5         60  '2020/12/06'    102       127     300.0  None
# 6         60  '2020/12/07'    110       136     374.0  None
# 7        450  '2020/12/08'    104       134     253.3  None
# 8         30  '2020/12/09'    109       133     195.1  None
# 9         60  '2020/12/10'     98       124     269.0  None
# 10        60  '2020/12/11'    103       147     329.3  None
# 11        60  '2020/12/12'    100       120     250.7  None
# 12        60  '2020/12/12'    100       120     250.7  None
# 13        60  '2020/12/13'    106       128     345.3  None
# 14        60  '2020/12/14'    104       132     379.3  None
# ...
