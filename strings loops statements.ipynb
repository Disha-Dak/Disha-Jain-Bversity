# %% [markdown]
# #if,else,else if

# %%
name="Gita"

# %%
name="Disha"

# %%
if name != "Disha":
   print("Okay")
else:
   print("name is not equal to subho")
# Out:
# name is not equal to subho

# %%
if name != "Disha":
   print("Okay")                        #Name not equal to disha, then its printing okay,the code breaks.
elif name==Gita:
   print("hi"+name)
else:
   print("name is not equal to subho")
# Out:
# Okay

# %%
name="Gita"

# %%
if name != "Disha" and name != "Gita":
   print("Okay")
elif name=="Gita":
   print("hi " +name)
else:
   print("name is not equal to subho")
# Out:
# hi Gita

# %%
gene="cancer x"

# %%
gene="cancer y"

# %%
if name != "cancer x" and name != "cancer y":
   print("Okay")
elif name=="cancer y":
   print("positive")
else:
   print("negative")
# Out:
# Okay

# %%
gene="cancer x"

# %%
if name != "cancer x":
   print("Okay")
else:
   print("negative")
# Out:
# Okay

# %%
gene="cancer x"

# %%
if gene != "cancer x" and gene != "cancer y":
   print("Okay")
elif name=="cancer y":
   print("positive")
else:
   print("negative")
# Out:
# negative

# %%
if gene != "cancer x":
   print("Okay")
else:
   print("negative")
# Out:
# negative

# %%
gene="cancer y"

# %%
if gene != "cancer x" and gene != "cancer y":
   print("Okay")
elif gene=="cancer y":
   print("positive")
else:
   print("negative")
# Out:
# positive

# %% [markdown]
# password checker

# %%
name=input("give name")
password=input("give password")
# Out:
# give name Disha
# give password Disha1234

# %%
if name == "Disha" and password == "Disha1234":
   print("Welcome" + name)
elif name !="Disha":
   print("Wrong username")
else:
   print("the password is wrong")
# Out:
# Wrong username

# %%
name=input("name")
password=input("password")
# Out:
# name Disha
# password Disha1234

# %%
if name == "Disha" and password == "Disha1234":
   print("Welcome" + name)
elif name != "Disha":
   print("Wrong username")
else:
   print("the password is wrong")
# Out:
# WelcomeDisha

# %% [markdown]
# For Loop

# %%
name=["Disha","Subho","Yogitha"]

# %%
len(name)
# Out:
# 3

# %%
for items in name:
    print(items)
# Out:
# Disha
# Subho
# Yogitha

# %%
numbers=[1,2,3,4,5]

# %%
len(numbers)
# Out:
# 5

# %%
sum=0

# %%
for number in numbers:
    sum= sum+number

# %%
sum
# Out:
# 15

# %%
for items in name:
    print(items)
# Out:
# Disha
# Subho
# Yogitha

# %%
name=["Disha","Subho","Yogitha"]

# %%
# Out:
# Disha
# Subho
# Yogitha
# Do it yourself

# %%
for items in name:
    if items == "Disha":
     print("Present"+items)
    elif items== "Yugh":
     print("absent"+items)
    else:
     print("Do it yourself")
# Out:
# PresentDisha
# Do it yourself
# Do it yourself

# %%
for items in name:
    if items == "Disha":
     print("Present"+items)
    elif items== "Yugh":
     print("absent"+items)
    else:
     print("Do it yourself")
     break
# Out:
# PresentDisha
# Do it yourself

# %%
for items in name:
    if items == "Disha":
     print("Present"+items)
     continue
    elif items== "Yugh":
     print("absent"+items)
    else:
     print("Do it yourself")
     break
# Out:
# PresentDisha
# Do it yourself

# %%
for items in name:
    if items == "Disha":
     print("Present"+items)
     continue
    elif items== "Yugh":
     print("absent"+items)
     break
    else:
     print("Do it yourself")
     break
# Out:
# PresentDisha
# Do it yourself

# %% [markdown]
# While

# %%
age=0

# %%
while age <=18:
  if age==18:                                     #Code not working 
    print("go and vote, your age" +str(age))

age=age+1

# %%
age
# Out:
# 19

# %%
"Go and vote you age is" +str(age)
# Out:
# 'Go and vote you age is20'

# %%
 salutation=f"Go and vote your age is {age}"

# %%
salutaion.format(age=19)
# Out:
# 'Go and vote your age is19'

# %%
message=f"Hi(name),how are you doing"

# %%
name
# Out:
# ['Disha', 'Subho', 'Yogitha']

# %%
name="Gita"

# %%
name
# Out:
# 'Gita'

# %%
message=f"hi {name},how are you doing)"

# %%
message.format(name=Disha)

# %%
Name=input()
Password=input()
# Out:
#  Disha
#  Disha1234

# %%
if Name == "Disha" and Password != "Disha1234":
   print("Welcome to the site")
elif Name!= "Disha":
   print("Check password")
else:
    print("Try again later")
# Out:
# Try again later

# %%
age=0

# %%
while age <=18:
  if age==18:
    print("go and vote, your age" +str(age))
    age=age+1
