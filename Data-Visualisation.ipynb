# %%
import pandas as pd

# %%
df = pd.read_csv("gene_expression_data - Sheet1.csv")

# %%
df
# Out:
#     Time  GeneA  GeneB  GeneC  Condition
# 0      0    5.1    4.8    6.2    Control
# 1      1    5.5    5.0    6.5    Control
# 2      2    5.7    5.2    6.7    Control
# 3      3    5.9    5.3    6.9    Control
# 4      4    6.1    5.5    7.0    Control
# 5      5    6.3    5.7    7.1    Control
# 6      0    4.9    4.5    6.0  Treatment
# 7      1    5.2    4.7    6.3  Treatment
# 8      2    5.4    4.9    6.5  Treatment
# 9      3    5.6    5.0    6.7  Treatment
# 10     4    5.8    5.2    6.8  Treatment
# 11     5    6.0    5.4    7.0  Treatment

# %%
gene_name = "GeneA"

# %%
df_gene = df[['Time', gene_name,
'Condition']].rename(columns={gene_name: 'Expression_Level'})

# %%
df_gene
# Out:
#     Time  Expression_Level  Condition
# 0      0               5.1    Control
# 1      1               5.5    Control
# 2      2               5.7    Control
# 3      3               5.9    Control
# 4      4               6.1    Control
# 5      5               6.3    Control
# 6      0               4.9  Treatment
# 7      1               5.2  Treatment
# 8      2               5.4  Treatment
# 9      3               5.6  Treatment
# 10     4               5.8  Treatment
# 11     5               6.0  Treatment

# %%
import plotly.express as px

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.lineplot(df_gene, x='Time', y='Expression_Level', hue='Condition')
# Out:
# <Axes: xlabel='Time', ylabel='Expression_Level'>

# %%
fig = px.line(df_gene, x='Time', y='Expression_Level',
color='Condition')
fig.show()

# %%
gene_nameb = "GeneB"

# %%
df_geneb = df[['Time', gene_nameb,
'Condition']].rename(columns={gene_nameb: 'Expression_Level'})
print(df_geneb)
# Out:
#     Time  Expression_Level  Condition
# 0      0               4.8    Control
# 1      1               5.0    Control
# 2      2               5.2    Control
# 3      3               5.3    Control
# 4      4               5.5    Control
# 5      5               5.7    Control
# 6      0               4.5  Treatment
# 7      1               4.7  Treatment
# 8      2               4.9  Treatment
# 9      3               5.0  Treatment
# 10     4               5.2  Treatment
# 11     5               5.4  Treatment

# %%
fig = px.line(df_geneb, x='Time', y='Expression_Level',
color='Condition')
fig.show()

# %%
gene_namec = "GeneC"

# %%
df_genec = df[['Time', gene_namec,
'Condition']].rename(columns={gene_namec: 'Expression_Level'})
print(df_genec)
# Out:
#     Time  Expression_Level  Condition
# 0      0               6.2    Control
# 1      1               6.5    Control
# 2      2               6.7    Control
# 3      3               6.9    Control
# 4      4               7.0    Control
# 5      5               7.1    Control
# 6      0               6.0  Treatment
# 7      1               6.3  Treatment
# 8      2               6.5  Treatment
# 9      3               6.7  Treatment
# 10     4               6.8  Treatment
# 11     5               7.0  Treatment

# %%
fig = px.line(df_genec, x= 'Time' , y = 'Expression_Level', color = 'Condition')
fig.show()

# %%
#Compare the average expression levels of multiple genes across different conditions
fig = px.bar(df_gene_final, x= 'Time' , y = 'Expression_Level', color = 'Condition')
fig.show()

# %%
#Bar Chart
# Reshape the data to have 'Gene' and 'Expression_Level' 
df_melted = df.melt(id_vars=['Time', 'Condition'],
value_vars=['GeneA', 'GeneB', 'GeneC'],
var_name='Gene', value_name='Expression_Level')
# Calculate the average expression level for each gene across conditions
df_avg = df_melted.groupby(['Gene', 'Condition']) ['Expression_Level'].mean().reset_index()
# Bar chart for average expression levels of each gene across conditions
fig = px.bar(df_avg, x='Gene', y='Expression_Level',
color='Condition', barmode='group',
   title="Average Expression Levels of Genes Across Conditions")

fig.update_layout(xaxis_title="Gene", yaxis_title="Average Expression Level")
fig.show()

# %%
#Bar Chart
# Reshape the data to have 'Gene' and 'Expression_Level' columns for
df_melted = df.melt(id_vars=['Time', 'Condition'],
value_vars=['GeneA', 'GeneB', 'GeneC'],
var_name='Gene', value_name='Expression_Level')
# Calculate the average expression level for each gene across conditions
df_avg = df_melted.groupby(['Gene', 'Condition']) ['Expression_Level'].mean().reset_index()
print(df_avg)
# Out:
#     Gene  Condition  Expression_Level
# 0  GeneA    Control          5.766667
# 1  GeneA  Treatment          5.483333
# 2  GeneB    Control          5.250000
# 3  GeneB  Treatment          4.950000
# 4  GeneC    Control          6.733333
# 5  GeneC  Treatment          6.550000

# %%
#Histogram:Plot the distribution of patient ages.
df_1 = pd.read_csv("patient_data - Sheet1.csv")

# %%
df_1
# Out:
#    PatientID  Age Gender DiseaseStatus TreatmentOutcome
# 0          1   45      M       Disease         Positive
# 1          2   50      F       Healthy         Negative
# 2          3   36      M       Disease         Positive
# 3          4   62      F       Disease         Negative
# 4          5   28      M       Healthy         Negative
# 5          6   40      F       Disease         Positive
# 6          7   35      M       Healthy         Negative
# 7          8   55      F       Disease         Negative
# 8          9   47      M       Disease         Positive
# 9         10   53      F       Disease         Negative

# %%
fig = px.histogram(df_1, x='Age', nbins=10,title = 'Age distribution over time')
fig.update_layout(xaxis_title="Age", yaxis_title="Count")
fig.show()

# %%
#Visualize the relationship between patient age and treatment outcome.
fig = px.scatter(df_1 , x  = 'Age' , y = 'TreatmentOutcome',color = 'TreatmentOutcome' )
fig.show()

# %%
df_2 = pd.read_csv("clinical_trial_data - Sheet1-2.csv")

# %%
df_2
# Out:
#    PatientID      Group  Outcome
# 0          1    Control      5.1
# 1          2    Control      4.8
# 2          3    Control      5.5
# 3          4    Control      5.0
# 4          5    Control      5.2
# 5          6  Treatment      5.9
# 6          7  Treatment      5.6
# 7          8  Treatment      5.8
# 8          9  Treatment      6.0
# 9         10  Treatment      5.7

# %%
fig = px.box(df_2 , x= 'Group', y = 'Outcome', title = 'Distribution of the outcome')
fig.show()

# %%
df
# Out:
#     Time  GeneA  GeneB  GeneC  Condition
# 0      0    5.1    4.8    6.2    Control
# 1      1    5.5    5.0    6.5    Control
# 2      2    5.7    5.2    6.7    Control
# 3      3    5.9    5.3    6.9    Control
# 4      4    6.1    5.5    7.0    Control
# 5      5    6.3    5.7    7.1    Control
# 6      0    4.9    4.5    6.0  Treatment
# 7      1    5.2    4.7    6.3  Treatment
# 8      2    5.4    4.9    6.5  Treatment
# 9      3    5.6    5.0    6.7  Treatment
# 10     4    5.8    5.2    6.8  Treatment
# 11     5    6.0    5.4    7.0  Treatment

# %%
df_melted = df.melt(id_vars=['Time', 'Condition'],
value_vars=['GeneA', 'GeneB', 'GeneC'],
var_name='Gene', value_name='Expression_Level')
# Create a pivot table to arrange genes across samples for the heatmap
heatmap_data = df_melted.pivot_table(index='Gene', columns='Time',
values='Expression_Level')
# Plot heatmap
fig = px.imshow(heatmap_data, aspect='auto',
color_continuous_scale='Viridis',
title='Gene Expression Levels Across Samples')
fig.update_layout(xaxis_title="Time", yaxis_title="Gene")
fig.show()

# %%
df_melted = df.melt(id_vars=['Time', 'Condition'],
value_vars=['GeneA', 'GeneB', 'GeneC'],
var_name='Gene', value_name='Expression_Level')
print(df_melted)
# Out:
#     Time  Condition   Gene  Expression_Level
# 0      0    Control  GeneA               5.1
# 1      1    Control  GeneA               5.5
# 2      2    Control  GeneA               5.7
# 3      3    Control  GeneA               5.9
# 4      4    Control  GeneA               6.1
# 5      5    Control  GeneA               6.3
# 6      0  Treatment  GeneA               4.9
# 7      1  Treatment  GeneA               5.2
# 8      2  Treatment  GeneA               5.4
# 9      3  Treatment  GeneA               5.6
# 10     4  Treatment  GeneA               5.8
# 11     5  Treatment  GeneA               6.0
# 12     0    Control  GeneB               4.8
# 13     1    Control  GeneB               5.0
# 14     2    Control  GeneB               5.2
# 15     3    Control  GeneB               5.3
# 16     4    Control  GeneB               5.5
# 17     5    Control  GeneB               5.7
# 18     0  Treatment  GeneB               4.5
# 19     1  Treatment  GeneB               4.7
# ...

# %%
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[113], line 2
#       1 # Combine the two tables
# ----> 2 df_combined = pd.concat([df, normalized_data], axis=1)
#       4 print(df_combined)
#
# NameError: name 'normalized_data' is not defined
